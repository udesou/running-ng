# %% [markdown]
# # A — Regression Dashboard
#
# **Audience:** anyone asking *"did this compiler change regress or improve the benchmarks?"*
#
# **Structure (Option C — per-comparison).** Every section under §4 corresponds to one comparison block declared in `runbms.yml` (or supplied via `COMPARISONS_OVERRIDE`). Each block is a self-contained story: instruction-count deltas, wall-time and max-RSS tornado plots per pair, a tradeoff scatter restricted to the block's variants, and ranked top-N regressions/improvements.
#
# When `runbms.yml` declares no `comparisons:` block, the loader falls back to a single default block (`BASELINE` vs every other variant) — the rendered output is then equivalent to a traditional single-baseline view.
#
# Configuration knobs are in the next cell. See [README.md §5.6](./README.md) for the YAML schema.

# %%
# Configuration — edit here, or override with BENCH_LOGS_DIR.
import os
from pathlib import Path

LOGS_DIR = Path(os.environ.get("BENCH_LOGS_DIR")
                or "../gc-sweep-logs/<SET-BENCH_LOGS_DIR>")
BASELINE = {"version": "5.4.1", "flags": "baseline"}
TOP_N    = 10
WARN_PCT = 1.0       # instruction-count verdict thresholds
REGRESS_PCT = 3.0

# When not None, ignore the runbms.yml `comparisons:` block and use this
# Python list instead. Same shape as the YAML schema. Useful for ad-hoc
# exploration without editing YAML or re-running benchmarks.
COMPARISONS_OVERRIDE = None
# Example:
# COMPARISONS_OVERRIDE = [
#     {"label": "flambda only", "a": "ocaml-5.4.1", "b": "ocaml-5.4.1-flambda"},
# ]

CACHE = Path.cwd() / "cache" / "macrobench.parquet"
if not LOGS_DIR.exists():
    raise SystemExit(
        f"LOGS_DIR does not exist: {LOGS_DIR.resolve()}\n"
        "Set BENCH_LOGS_DIR to your run directory, e.g.:\n"
        "  BENCH_LOGS_DIR=../gc-sweep-logs/monolith-2026-05-07-Thu-110013 jupyter ...\n"
        "or edit this cell."
    )
print("LOGS_DIR =", LOGS_DIR.resolve())
print("BASELINE =", BASELINE)
print("COMPARISONS_OVERRIDE =", COMPARISONS_OVERRIDE)

# %%
# %matplotlib inline
import sys
sys.path.insert(0, str(Path.cwd()))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

from macrobench_loader import (
    load_macro_dataframe, load_comparisons, audit_comparison_coverage,
    instruction_count_deltas,
)

pd.set_option("display.max_columns", 80)
pd.set_option("display.width", 160)

# %% [markdown]
# ## 1. Load
#
# Parses every `.log` + `olly_*.json` + `perf_*.json` in `LOGS_DIR` and writes a parquet cache. Subsequent runs read the cache. Delete `cache/macrobench.parquet` to force a rebuild.

# %%
if CACHE.exists():
    df = pd.read_parquet(CACHE)
    print(f"Loaded cache: {CACHE}  shape={df.shape}")
else:
    df = load_macro_dataframe(LOGS_DIR)
    CACHE.parent.mkdir(exist_ok=True)
    df.to_parquet(CACHE)
    print(f"Built cache:  {CACHE}  shape={df.shape}")

variants = sorted(df["variant"].unique())
benches  = sorted(df["benchmark"].unique())
print(f"{len(benches)} benchmarks × {len(variants)} variants")
print("variants:", variants)
# Out:
# Loaded cache: /home/udesou/running-ng/notebooks/cache/macrobench.parquet  shape=(624, 47)
# 26 benchmarks × 8 variants
# variants: ['5.4.1/baseline', '5.4.1/flambda', '5.4.1/fp', '5.4.1/fp-flambda', 'd8bb46c/baseline', 'd8bb46c/flambda', 'd8bb46c/fp', 'd8bb46c/fp-flambda']

# %% [markdown]
# ## 2. Sanity & schema
#
# Three checks before any plotting:
#
# 1. **Completeness** — for every (benchmark, variant) cell, how many invocations were recorded?
# 2. **NaN audit** — which metric columns are partially or fully empty?
# 3. **Schema sanity** — does every declared runtime have data, and is every loaded variant rendered by some comparison block?

# %%
completeness = df.pivot_table(
    index="benchmark", columns="variant",
    values="olly_wall_time_s", aggfunc="count",
).fillna(0).astype(int)

print(f"Completeness: {(completeness > 0).sum().sum()} / {completeness.size} cells populated")
print(f"Invocations per cell: min={completeness.values.min()}  max={completeness.values.max()}")
missing = completeness[(completeness == 0).any(axis=1)]
if not missing.empty:
    print("\nBenchmarks with missing variants:")
    print(missing)

fig, ax = plt.subplots(figsize=(1.2 * len(variants) + 2, max(3, 0.3 * len(benches))))
vmax = max(completeness.values.max(), 1)
im = ax.imshow(completeness.values, aspect="auto", cmap="Greens", vmin=0, vmax=vmax)
ax.set_xticks(range(len(completeness.columns)))
ax.set_xticklabels(completeness.columns, rotation=60, ha="right")
ax.set_yticks(range(len(completeness.index)))
ax.set_yticklabels(completeness.index)
for (i, j), v in np.ndenumerate(completeness.values):
    ax.text(j, i, str(v), ha="center", va="center", fontsize=8,
            color="white" if v >= vmax / 2 else "black")
ax.set_title("Invocations per (benchmark, variant)")
fig.colorbar(im, ax=ax, label="invocations", shrink=0.7)
plt.tight_layout()
plt.show()
completeness
# Out:
# Completeness: 208 / 208 cells populated
# Invocations per cell: min=3  max=3
# variant              5.4.1/baseline  5.4.1/flambda  5.4.1/fp  5.4.1/fp-flambda  d8bb46c/baseline  d8bb46c/flambda  d8bb46c/fp  d8bb46c/fp-flambda
# benchmark
# alt_ergo_fill                     3              3         3                 3                 3                3           3                   3
# alt_ergo_unsat_smt2               3              3         3                 3                 3                3           3                   3
# alt_ergo_yyll                     3              3         3                 3                 3                3           3                   3
# coqc_corelib_stress               3              3         3                 3                 3                3           3                   3
# cpdf_blacktext                    3              3         3                 3                 3                3           3                   3
# cpdf_merge                        3              3         3                 3                 3                3           3                   3
# cpdf_scale                        3              3         3                 3                 3                3           3                   3
# cpdf_squeeze                      3              3         3                 3                 3                3           3                   3
# devkit_gzip                       3              3         3                 3                 3                3           3                   3
# devkit_htmlstream                 3              3         3                 3                 3                3           3                   3
# devkit_network                    3              3         3                 3                 3                3           3                   3
# devkit_stre                       3              3         3                 3                 3                3           3                   3
# dune_bootstrap                    3              3         3                 3                 3                3           3                   3
# eio_fiber_stream                  3              3         3                 3                 3                3           3                   3
# irmin_mem_rw                      3              3         3                 3                 3                3           3                   3
# liq_parse_typecheck               3              3         3                 3                 3                3           3                   3
# menhir_ocamly                     3              3         3                 3                 3                3           3                   3
# menhir_sql_parser                 3              3         3                 3                 3                3           3                   3
# menhir_sysver                     3              3         3                 3                 3                3           3                   3
# ocamlformat_rocq                  3              3         3                 3                 3                3           3                   3
# owl_gc                            3              3         3                 3                 3                3           3                   3
# pplacer_testsuite                 3              3         3                 3                 3                3           3                   3
# sedlex_tokenize                   3              3         3                 3                 3                3           3                   3
# test_decompress                   3              3         3                 3                 3                3           3                   3
# ydump_repeat                      3              3         3                 3                 3                3           3                   3
# zarith_pi                         3              3         3                 3                 3                3           3                   3

# %%
# NaN audit
nan_counts = df.isna().sum().sort_values(ascending=False)
nan_counts[nan_counts > 0].head(20)
# Out:
# s                         624
# o                         624
# perf_page-faults_sec      580
# perf_page-faults_k_sec     44
# dtype: int64

# %%
# Resolve comparisons (from YAML or override) and audit schema coverage.
comparisons = load_comparisons(
    LOGS_DIR, all_variants=variants,
    baseline=BASELINE, override=COMPARISONS_OVERRIDE,
)
audit = audit_comparison_coverage(LOGS_DIR, df, comparisons)

print("Comparisons declared:")
for c in comparisons:
    print(f"  - {c.label!r}  ({len(c.pairs)} pair{'s' if len(c.pairs) != 1 else ''})")

print(
    f"\nVariant coverage: {audit.comparison_variants_total} / "
    f"{audit.data_variants_total} data variants are referenced by a comparison block."
)
if audit.declared_runtimes_no_data:
    print(
        "\nWARNING: runtimes declared in `runbms.yml runtimes:` but no data "
        "present in the dataset:\n  " + ", ".join(audit.declared_runtimes_no_data)
    )
    print("  → Likely declared but not referenced by any `configs:` entry, "
          "or the run failed for these.")
if audit.data_variants_uncovered:
    print(
        "\nWARNING: variants loaded from the dataset but not rendered by any "
        "comparison block:\n  " + ", ".join(audit.data_variants_uncovered)
    )
    print("  → Add a comparison block (or COMPARISONS_OVERRIDE) that mentions them, "
          "or accept the omission.")
# Out:
# Comparisons declared:
#   - '5.4.1 flag effects'  (3 pairs)
#   - 'd8bb46c flag effects'  (3 pairs)
#   - 'version effect (by flag combo)'  (4 pairs)
#
# Variant coverage: 8 / 8 data variants are referenced by a comparison block.

# %% [markdown]
# ## 3. Comparisons overview
#
# One row per declared comparison block, summarising regression/improvement counts and worst/best wall-time Δ. Use this to decide which block in §4 to read first.

# %%
def _delta_per_bench(df, av, bv, metric):
    """Δ% per benchmark for the median ratio of (b vs a)."""
    a = df[df["variant"] == av].groupby("benchmark")[metric].median()
    b = df[df["variant"] == bv].groupby("benchmark")[metric].median()
    return ((b / a) - 1.0).dropna() * 100.0


overview_rows = []
for cmp in comparisons:
    deltas = []
    for av, bv in cmp.pairs:
        d = _delta_per_bench(df, av, bv, "olly_wall_time_s")
        deltas.extend(d.values)
    deltas = np.array(deltas)
    if deltas.size == 0:
        overview_rows.append({"block": cmp.label, "pairs": len(cmp.pairs),
                              "datapoints": 0, "regressions ≥1%": 0,
                              "improvements ≤−1%": 0, "worst Δ%": np.nan,
                              "best Δ%": np.nan})
        continue
    overview_rows.append({
        "block": cmp.label,
        "pairs": len(cmp.pairs),
        "datapoints": deltas.size,
        "regressions ≥1%":  int((deltas >=  WARN_PCT).sum()),
        "improvements ≤−1%": int((deltas <= -WARN_PCT).sum()),
        "worst Δ%": round(float(deltas.max()), 2),
        "best Δ%":  round(float(deltas.min()), 2),
    })
overview = pd.DataFrame(overview_rows)
overview
# Out:
#                             block  pairs  datapoints  regressions ≥1%  improvements ≤−1%  worst Δ%  best Δ%
# 0              5.4.1 flag effects      3          78               29                 31     45.71   -25.66
# 1            d8bb46c flag effects      3          78               24                 37      7.74   -28.80
# 2  version effect (by flag combo)      4         104               53                 16     47.43   -30.11

# %% [markdown]
# ## 4. Per-comparison detail
#
# One subsection per comparison block. The cell below defines small render helpers; the next cell loops them across every block.

# %%
def _tornado_grid(cmp, df, metric, metric_label, benches):
    n_pairs = len(cmp.pairs)
    if n_pairs == 0:
        return
    ncols = min(2, n_pairs)
    nrows = (n_pairs + ncols - 1) // ncols
    height = max(3.0, 0.22 * len(benches)) * nrows + 0.5
    fig, axes = plt.subplots(nrows, ncols, figsize=(7.2 * ncols, height), squeeze=False)
    for (av, bv), ax in zip(cmp.pairs, axes.flat):
        d = _delta_per_bench(df, av, bv, metric).reindex(benches).dropna().sort_values()
        if d.empty:
            ax.text(0.5, 0.5, "no data", ha="center", va="center", transform=ax.transAxes)
            ax.set_title(f"{av}  →  {bv}", fontsize=10)
            continue
        colors = ["#2a9d8f" if x < 0 else "#e76f51" for x in d.values]
        ax.barh(d.index, d.values, color=colors)
        ax.axvline(0, color="black", linewidth=0.7)
        ax.set_title(f"{av}  →  {bv}", fontsize=10)
        ax.set_xlabel(f"{metric_label} Δ%", fontsize=8)
        ax.tick_params(axis="y", labelsize=7)
    for ax in axes.flat[n_pairs:]:
        ax.axis("off")
    fig.suptitle(f"{cmp.label} — {metric_label}", y=1.00, fontsize=11)
    plt.tight_layout()
    plt.show()


def _ranked_block_table(cmp, df, metric, metric_label, top_n):
    rows = []
    for av, bv in cmp.pairs:
        d = _delta_per_bench(df, av, bv, metric)
        for bench, v in d.items():
            rows.append({"benchmark": bench, "a": av, "b": bv, f"{metric_label}_Δ%": round(v, 3)})
    if not rows:
        print(f"  ({metric_label}: no resolvable data)")
        return
    summary = pd.DataFrame(rows)
    print(f"\n{metric_label}: top {top_n} regressions")
    print(summary.sort_values(f"{metric_label}_Δ%", ascending=False).head(top_n).to_string(index=False))
    print(f"\n{metric_label}: top {top_n} improvements")
    print(summary.sort_values(f"{metric_label}_Δ%").head(top_n).to_string(index=False))


def _instruction_count_table(cmp, df, top_n, warn_pct, regress_pct):
    if "perf_instructions" not in df.columns or df["perf_instructions"].isna().all():
        print("  (perf_instructions not available — skipping)")
        return
    rows = []
    for av, bv in cmp.pairs:
        d = _delta_per_bench(df, av, bv, "perf_instructions")
        for bench, v in d.items():
            verdict = (
                "improvement" if v <= -regress_pct
                else "regression" if v >=  regress_pct
                else "warn"        if abs(v) >= warn_pct
                else "neutral"
            )
            rows.append({"benchmark": bench, "a": av, "b": bv,
                         "instructions Δ%": round(v, 3), "verdict": verdict})
    if not rows:
        print("  (no data)")
        return
    t = pd.DataFrame(rows).sort_values("instructions Δ%", ascending=False)
    counts = t["verdict"].value_counts().to_dict()
    print(f"  Verdict counts: {counts}")
    print(f"\n  top {top_n} regressions")
    print(t.head(top_n).to_string(index=False))
    print(f"\n  top {top_n} improvements")
    print(t.tail(top_n).iloc[::-1].to_string(index=False))


def _tradeoff_scatter_block(cmp, df):
    if "max_rss_mb" not in df.columns or df["max_rss_mb"].isna().all():
        print("  (max_rss_mb not available — skipping tradeoff scatter)")
        return
    rows = []
    for av, bv in cmp.pairs:
        wall_d = _delta_per_bench(df, av, bv, "olly_wall_time_s")
        rss_d  = _delta_per_bench(df, av, bv, "max_rss_mb")
        common = wall_d.index.intersection(rss_d.index)
        for bench in common:
            rows.append({"benchmark": bench, "pair": f"{av} → {bv}",
                         "wall_ratio": 1.0 + wall_d[bench] / 100.0,
                         "rss_ratio":  1.0 + rss_d[bench]  / 100.0})
    if not rows:
        print("  (tradeoff: no rows)")
        return
    pts = pd.DataFrame(rows)
    pairs_unique = sorted(pts["pair"].unique())
    fig, ax = plt.subplots(figsize=(8, 7))
    palette = plt.colormaps["tab10"].resampled(max(len(pairs_unique), 10))
    for i, p in enumerate(pairs_unique):
        sub = pts[pts["pair"] == p]
        ax.scatter(sub["wall_ratio"], sub["rss_ratio"], color=palette(i), label=p, alpha=0.75, s=35)
    ax.axhline(1.0, color="gray", linewidth=0.5, linestyle="--")
    ax.axvline(1.0, color="gray", linewidth=0.5, linestyle="--")
    ax.set_xlabel("wall time ratio  (b / a)")
    ax.set_ylabel("max RSS ratio  (b / a)")
    ax.set_title(f"{cmp.label} — time × memory tradeoff")
    ax.legend(loc="center left", bbox_to_anchor=(1.02, 0.5), frameon=False, fontsize=9)
    plt.tight_layout()
    plt.show()


def render_block(cmp, df, benches, top_n=10, warn_pct=1.0, regress_pct=3.0):
    display(Markdown(f"### {cmp.label}"))
    pair_lines = "\n".join(f"- `{a}`  →  `{b}`" for a, b in cmp.pairs)
    display(Markdown(f"**Pairs ({len(cmp.pairs)}):**\n\n{pair_lines}"))

    display(Markdown("#### Instruction-count Δ%"))
    _instruction_count_table(cmp, df, top_n, warn_pct, regress_pct)

    display(Markdown("#### Wall-time Δ% per pair"))
    _tornado_grid(cmp, df, "olly_wall_time_s", "wall time", benches)

    display(Markdown("#### Max RSS Δ% per pair"))
    _tornado_grid(cmp, df, "max_rss_mb", "max RSS", benches)

    if "olly_p95_latency_ms" in df.columns and df["olly_p95_latency_ms"].notna().any():
        display(Markdown("#### p95 latency Δ% per pair"))
        _tornado_grid(cmp, df, "olly_p95_latency_ms", "p95 latency", benches)
    if "olly_p99_latency_ms" in df.columns and df["olly_p99_latency_ms"].notna().any():
        display(Markdown("#### p99 latency Δ% per pair"))
        _tornado_grid(cmp, df, "olly_p99_latency_ms", "p99 latency", benches)

    display(Markdown("#### Time × memory tradeoff"))
    _tradeoff_scatter_block(cmp, df)

    display(Markdown("#### Ranked tables (within block)"))
    for metric, label in (
        ("olly_wall_time_s", "wall"),
        ("max_rss_mb", "rss"),
        ("olly_gc_overhead_pct", "gc_overhead"),
    ):
        if metric not in df.columns or df[metric].isna().all():
            continue
        _ranked_block_table(cmp, df, metric, label, top_n)
    print()  # spacing

# %%
for cmp in comparisons:
    render_block(cmp, df, benches, top_n=TOP_N,
                 warn_pct=WARN_PCT, regress_pct=REGRESS_PCT)
# Out:
# ### 5.4.1 flag effects
# **Pairs (3):**
#
# - `5.4.1/baseline`  →  `5.4.1/fp`
# - `5.4.1/baseline`  →  `5.4.1/flambda`
# - `5.4.1/baseline`  →  `5.4.1/fp-flambda`
# #### Instruction-count Δ%
#   Verdict counts: {'improvement': 25, 'regression': 24, 'neutral': 19, 'warn': 10}
#
#   top 10 regressions
#           benchmark              a                b  instructions Δ%    verdict
#         devkit_gzip 5.4.1/baseline         5.4.1/fp           20.208 regression
#         devkit_gzip 5.4.1/baseline    5.4.1/flambda           17.494 regression
#         devkit_gzip 5.4.1/baseline 5.4.1/fp-flambda           17.318 regression
#       alt_ergo_yyll 5.4.1/baseline         5.4.1/fp           13.441 regression
#    eio_fiber_stream 5.4.1/baseline         5.4.1/fp           10.210 regression
#        irmin_mem_rw 5.4.1/baseline         5.4.1/fp           10.017 regression
#       menhir_ocamly 5.4.1/baseline         5.4.1/fp            9.422 regression
# liq_parse_typecheck 5.4.1/baseline         5.4.1/fp            8.792 regression
#    ocamlformat_rocq 5.4.1/baseline         5.4.1/fp            8.682 regression
#     test_decompress 5.4.1/baseline         5.4.1/fp            8.026 regression
#
#   top 10 improvements
#           benchmark              a                b  instructions Δ%     verdict
#              owl_gc 5.4.1/baseline 5.4.1/fp-flambda          -33.791 improvement
#              owl_gc 5.4.1/baseline    5.4.1/flambda          -33.126 improvement
# liq_parse_typecheck 5.4.1/baseline    5.4.1/flambda          -23.608 improvement
# liq_parse_typecheck 5.4.1/baseline 5.4.1/fp-flambda          -17.818 improvement
#    ocamlformat_rocq 5.4.1/baseline    5.4.1/flambda          -13.040 improvement
#        irmin_mem_rw 5.4.1/baseline    5.4.1/flambda          -10.202 improvement
#       alt_ergo_yyll 5.4.1/baseline    5.4.1/flambda           -8.982 improvement
#       menhir_sysver 5.4.1/baseline    5.4.1/flambda           -8.601 improvement
#       menhir_ocamly 5.4.1/baseline    5.4.1/flambda           -7.983 improvement
#   menhir_sql_parser 5.4.1/baseline    5.4.1/flambda           -7.881 improvement
# #### Wall-time Δ% per pair
# #### Max RSS Δ% per pair
# #### p95 latency Δ% per pair
# #### p99 latency Δ% per pair
# #### Time × memory tradeoff
# #### Ranked tables (within block)
# wall: top 10 regressions
#         benchmark              a                b  wall_Δ%
#       devkit_gzip 5.4.1/baseline    5.4.1/flambda   45.714
#       devkit_gzip 5.4.1/baseline         5.4.1/fp   45.714
#       devkit_gzip 5.4.1/baseline 5.4.1/fp-flambda   44.000
# devkit_htmlstream 5.4.1/baseline         5.4.1/fp   15.807
#  eio_fiber_stream 5.4.1/baseline         5.4.1/fp    8.848
#       devkit_stre 5.4.1/baseline         5.4.1/fp    8.696
#       devkit_stre 5.4.1/baseline 5.4.1/fp-flambda    6.522
#     alt_ergo_fill 5.4.1/baseline         5.4.1/fp    5.882
#  ocamlformat_rocq 5.4.1/baseline         5.4.1/fp    5.805
#   sedlex_tokenize 5.4.1/baseline         5.4.1/fp    5.400
#
# wall: top 10 improvements
#           benchmark              a                b  wall_Δ%
#              owl_gc 5.4.1/baseline 5.4.1/fp-flambda  -25.660
#              owl_gc 5.4.1/baseline    5.4.1/flambda  -25.660
# liq_parse_typecheck 5.4.1/baseline    5.4.1/flambda  -22.642
# liq_parse_typecheck 5.4.1/baseline 5.4.1/fp-flambda  -19.637
#    ocamlformat_rocq 5.4.1/baseline    5.4.1/flambda   -9.551
#        irmin_mem_rw 5.4.1/baseline    5.4.1/flambda   -8.293
#       menhir_ocamly 5.4.1/baseline    5.4.1/flambda   -7.500
#     test_decompress 5.4.1/baseline    5.4.1/flambda   -7.018
#       menhir_sysver 5.4.1/baseline    5.4.1/flambda   -6.910
#     sedlex_tokenize 5.4.1/baseline    5.4.1/flambda   -6.331
#
# rss: top 10 regressions
#           benchmark              a                b  rss_Δ%
#   devkit_htmlstream 5.4.1/baseline    5.4.1/flambda  34.291
#   devkit_htmlstream 5.4.1/baseline 5.4.1/fp-flambda  34.291
#       alt_ergo_fill 5.4.1/baseline    5.4.1/flambda  34.243
#       alt_ergo_fill 5.4.1/baseline 5.4.1/fp-flambda  31.562
#              owl_gc 5.4.1/baseline    5.4.1/flambda  24.800
#              owl_gc 5.4.1/baseline 5.4.1/fp-flambda  21.962
# alt_ergo_unsat_smt2 5.4.1/baseline    5.4.1/flambda  10.968
# alt_ergo_unsat_smt2 5.4.1/baseline 5.4.1/fp-flambda  10.769
# liq_parse_typecheck 5.4.1/baseline 5.4.1/fp-flambda   8.036
#       menhir_ocamly 5.4.1/baseline         5.4.1/fp   7.990
#
# rss: top 10 improvements
#        benchmark              a                b  rss_Δ%
#    menhir_sysver 5.4.1/baseline    5.4.1/flambda  -5.355
#    menhir_sysver 5.4.1/baseline 5.4.1/fp-flambda  -5.288
#    alt_ergo_fill 5.4.1/baseline         5.4.1/fp  -3.735
# ocamlformat_rocq 5.4.1/baseline    5.4.1/flambda  -2.414
# ocamlformat_rocq 5.4.1/baseline 5.4.1/fp-flambda  -2.352
#      devkit_gzip 5.4.1/baseline         5.4.1/fp  -2.148
#  test_decompress 5.4.1/baseline 5.4.1/fp-flambda  -1.677
#  test_decompress 5.4.1/baseline    5.4.1/flambda  -1.534
#     ydump_repeat 5.4.1/baseline         5.4.1/fp  -1.380
#      devkit_stre 5.4.1/baseline         5.4.1/fp  -1.104
#
# gc_overhead: top 10 regressions
#         benchmark              a                b  gc_overhead_Δ%
#     menhir_sysver 5.4.1/baseline 5.4.1/fp-flambda           9.042
# menhir_sql_parser 5.4.1/baseline 5.4.1/fp-flambda           8.066
#     menhir_sysver 5.4.1/baseline    5.4.1/flambda           7.429
#     menhir_ocamly 5.4.1/baseline 5.4.1/fp-flambda           6.196
# menhir_sql_parser 5.4.1/baseline    5.4.1/flambda           6.114
#     menhir_ocamly 5.4.1/baseline    5.4.1/flambda           5.226
#    cpdf_blacktext 5.4.1/baseline 5.4.1/fp-flambda           4.978
#     alt_ergo_fill 5.4.1/baseline    5.4.1/flambda           4.926
#     alt_ergo_fill 5.4.1/baseline 5.4.1/fp-flambda           4.706
#   sedlex_tokenize 5.4.1/baseline 5.4.1/fp-flambda           4.640
#
# gc_overhead: top 10 improvements
#           benchmark              a                b  gc_overhead_Δ%
#         devkit_gzip 5.4.1/baseline    5.4.1/flambda         -52.632
#         devkit_gzip 5.4.1/baseline 5.4.1/fp-flambda         -51.974
#         devkit_gzip 5.4.1/baseline         5.4.1/fp         -45.395
#              owl_gc 5.4.1/baseline 5.4.1/fp-flambda         -38.475
#              owl_gc 5.4.1/baseline    5.4.1/flambda         -37.255
# liq_parse_typecheck 5.4.1/baseline 5.4.1/fp-flambda         -33.959
# liq_parse_typecheck 5.4.1/baseline    5.4.1/flambda         -32.924
#   devkit_htmlstream 5.4.1/baseline    5.4.1/flambda         -22.343
#   devkit_htmlstream 5.4.1/baseline 5.4.1/fp-flambda         -20.436
#     test_decompress 5.4.1/baseline 5.4.1/fp-flambda         -13.866
# ### d8bb46c flag effects
# **Pairs (3):**
#
# - `d8bb46c/baseline`  →  `d8bb46c/fp`
# - `d8bb46c/baseline`  →  `d8bb46c/flambda`
# - `d8bb46c/baseline`  →  `d8bb46c/fp-flambda`
# #### Instruction-count Δ%
#   Verdict counts: {'regression': 23, 'improvement': 22, 'neutral': 17, 'warn': 16}
#
#   top 10 regressions
#           benchmark                a          b  instructions Δ%    verdict
#       alt_ergo_yyll d8bb46c/baseline d8bb46c/fp           13.268 regression
# alt_ergo_unsat_smt2 d8bb46c/baseline d8bb46c/fp           11.775 regression
#    eio_fiber_stream d8bb46c/baseline d8bb46c/fp           10.130 regression
#        irmin_mem_rw d8bb46c/baseline d8bb46c/fp            9.668 regression
#       menhir_ocamly d8bb46c/baseline d8bb46c/fp            8.541 regression
# liq_parse_typecheck d8bb46c/baseline d8bb46c/fp            8.180 regression
#    ocamlformat_rocq d8bb46c/baseline d8bb46c/fp            8.125 regression
#     test_decompress d8bb46c/baseline d8bb46c/fp            7.928 regression
#   menhir_sql_parser d8bb46c/baseline d8bb46c/fp            7.351 regression
#   devkit_htmlstream d8bb46c/baseline d8bb46c/fp            7.011 regression
#
#   top 10 improvements
#           benchmark                a                  b  instructions Δ%     verdict
# liq_parse_typecheck d8bb46c/baseline    d8bb46c/flambda          -30.126 improvement
#              owl_gc d8bb46c/baseline    d8bb46c/flambda          -26.043 improvement
#              owl_gc d8bb46c/baseline d8bb46c/fp-flambda          -25.306 improvement
# liq_parse_typecheck d8bb46c/baseline d8bb46c/fp-flambda          -24.743 improvement
#    ocamlformat_rocq d8bb46c/baseline    d8bb46c/flambda          -11.963 improvement
#        irmin_mem_rw d8bb46c/baseline    d8bb46c/flambda          -10.319 improvement
#       menhir_ocamly d8bb46c/baseline    d8bb46c/flambda           -8.911 improvement
#       alt_ergo_yyll d8bb46c/baseline    d8bb46c/flambda           -8.228 improvement
#     sedlex_tokenize d8bb46c/baseline    d8bb46c/flambda           -7.966 improvement
#       menhir_sysver d8bb46c/baseline    d8bb46c/flambda           -7.806 improvement
# #### Wall-time Δ% per pair
# #### Max RSS Δ% per pair
# #### p95 latency Δ% per pair
# #### p99 latency Δ% per pair
# #### Time × memory tradeoff
# #### Ranked tables (within block)
# wall: top 10 regressions
#         benchmark                a                  b  wall_Δ%
#  eio_fiber_stream d8bb46c/baseline         d8bb46c/fp    7.744
#       devkit_stre d8bb46c/baseline d8bb46c/fp-flambda    6.522
#       devkit_stre d8bb46c/baseline         d8bb46c/fp    6.522
# devkit_htmlstream d8bb46c/baseline         d8bb46c/fp    6.242
#  eio_fiber_stream d8bb46c/baseline d8bb46c/fp-flambda    5.724
#     alt_ergo_fill d8bb46c/baseline         d8bb46c/fp    5.556
#   sedlex_tokenize d8bb46c/baseline         d8bb46c/fp    5.461
#        cpdf_scale d8bb46c/baseline         d8bb46c/fp    5.117
#   test_decompress d8bb46c/baseline         d8bb46c/fp    4.854
#  ocamlformat_rocq d8bb46c/baseline         d8bb46c/fp    4.317
#
# wall: top 10 improvements
#           benchmark                a                  b  wall_Δ%
# liq_parse_typecheck d8bb46c/baseline    d8bb46c/flambda  -28.797
# liq_parse_typecheck d8bb46c/baseline d8bb46c/fp-flambda  -25.064
#              owl_gc d8bb46c/baseline    d8bb46c/flambda  -23.529
#              owl_gc d8bb46c/baseline d8bb46c/fp-flambda  -22.460
#        irmin_mem_rw d8bb46c/baseline    d8bb46c/flambda  -16.642
#        irmin_mem_rw d8bb46c/baseline d8bb46c/fp-flambda  -12.144
#    ocamlformat_rocq d8bb46c/baseline    d8bb46c/flambda   -8.453
#     test_decompress d8bb46c/baseline    d8bb46c/flambda   -7.573
#       menhir_ocamly d8bb46c/baseline    d8bb46c/flambda   -7.317
#       menhir_sysver d8bb46c/baseline    d8bb46c/flambda   -7.133
#
# rss: top 10 regressions
#           benchmark                a                  b  rss_Δ%
#   devkit_htmlstream d8bb46c/baseline    d8bb46c/flambda  59.257
#   devkit_htmlstream d8bb46c/baseline d8bb46c/fp-flambda  59.093
#       alt_ergo_fill d8bb46c/baseline    d8bb46c/flambda  40.012
#       alt_ergo_fill d8bb46c/baseline d8bb46c/fp-flambda  37.753
# alt_ergo_unsat_smt2 d8bb46c/baseline    d8bb46c/flambda  16.699
# alt_ergo_unsat_smt2 d8bb46c/baseline d8bb46c/fp-flambda  16.628
#        irmin_mem_rw d8bb46c/baseline d8bb46c/fp-flambda   9.181
#        irmin_mem_rw d8bb46c/baseline    d8bb46c/flambda   9.007
#   pplacer_testsuite d8bb46c/baseline d8bb46c/fp-flambda   8.537
#   pplacer_testsuite d8bb46c/baseline    d8bb46c/flambda   8.341
#
# rss: top 10 improvements
#         benchmark                a                  b  rss_Δ%
# menhir_sql_parser d8bb46c/baseline    d8bb46c/flambda -12.880
# menhir_sql_parser d8bb46c/baseline d8bb46c/fp-flambda -12.830
#     menhir_ocamly d8bb46c/baseline         d8bb46c/fp  -5.786
#     menhir_ocamly d8bb46c/baseline    d8bb46c/flambda  -5.272
#     menhir_ocamly d8bb46c/baseline d8bb46c/fp-flambda  -5.164
#     menhir_sysver d8bb46c/baseline    d8bb46c/flambda  -1.975
#     menhir_sysver d8bb46c/baseline d8bb46c/fp-flambda  -1.955
#  ocamlformat_rocq d8bb46c/baseline d8bb46c/fp-flambda  -1.921
#  ocamlformat_rocq d8bb46c/baseline         d8bb46c/fp  -1.833
#  ocamlformat_rocq d8bb46c/baseline    d8bb46c/flambda  -1.791
#
# gc_overhead: top 10 regressions
#         benchmark                a                  b  gc_overhead_Δ%
#     menhir_ocamly d8bb46c/baseline    d8bb46c/flambda           7.864
#     menhir_ocamly d8bb46c/baseline d8bb46c/fp-flambda           7.107
#     menhir_sysver d8bb46c/baseline d8bb46c/fp-flambda           7.015
#     menhir_sysver d8bb46c/baseline    d8bb46c/flambda           6.955
# menhir_sql_parser d8bb46c/baseline d8bb46c/fp-flambda           5.451
#      cpdf_squeeze d8bb46c/baseline d8bb46c/fp-flambda           5.362
# menhir_sql_parser d8bb46c/baseline    d8bb46c/flambda           5.177
#      irmin_mem_rw d8bb46c/baseline    d8bb46c/flambda           4.892
#    cpdf_blacktext d8bb46c/baseline d8bb46c/fp-flambda           4.746
#  ocamlformat_rocq d8bb46c/baseline    d8bb46c/flambda           4.386
#
# gc_overhead: top 10 improvements
#           benchmark                a                  b  gc_overhead_Δ%
#              owl_gc d8bb46c/baseline    d8bb46c/flambda         -62.512
#              owl_gc d8bb46c/baseline d8bb46c/fp-flambda         -61.882
# liq_parse_typecheck d8bb46c/baseline d8bb46c/fp-flambda         -51.242
# liq_parse_typecheck d8bb46c/baseline    d8bb46c/flambda         -49.693
#   devkit_htmlstream d8bb46c/baseline d8bb46c/fp-flambda         -20.936
#   devkit_htmlstream d8bb46c/baseline    d8bb46c/flambda         -18.473
#           zarith_pi d8bb46c/baseline    d8bb46c/flambda         -17.818
#         devkit_gzip d8bb46c/baseline    d8bb46c/flambda         -17.742
#     test_decompress d8bb46c/baseline d8bb46c/fp-flambda         -16.944
#           zarith_pi d8bb46c/baseline d8bb46c/fp-flambda         -16.909
# ### version effect (by flag combo)
# **Pairs (4):**
#
# - `5.4.1/baseline`  →  `d8bb46c/baseline`
# - `5.4.1/fp`  →  `d8bb46c/fp`
# - `5.4.1/flambda`  →  `d8bb46c/flambda`
# - `5.4.1/fp-flambda`  →  `d8bb46c/fp-flambda`
# #### Instruction-count Δ%
#   Verdict counts: {'regression': 43, 'neutral': 38, 'warn': 17, 'improvement': 6}
#
#   top 10 regressions
#           benchmark                a                  b  instructions Δ%    verdict
#         devkit_gzip   5.4.1/baseline   d8bb46c/baseline           18.978 regression
#          cpdf_merge   5.4.1/baseline   d8bb46c/baseline           10.928 regression
#          cpdf_merge    5.4.1/flambda    d8bb46c/flambda           10.377 regression
#          cpdf_merge         5.4.1/fp         d8bb46c/fp           10.178 regression
#          cpdf_merge 5.4.1/fp-flambda d8bb46c/fp-flambda            9.862 regression
#       menhir_sysver    5.4.1/flambda    d8bb46c/flambda            9.144 regression
#       menhir_sysver 5.4.1/fp-flambda d8bb46c/fp-flambda            8.693 regression
#        cpdf_squeeze    5.4.1/flambda    d8bb46c/flambda            8.534 regression
# liq_parse_typecheck   5.4.1/baseline   d8bb46c/baseline            8.345 regression
#        cpdf_squeeze 5.4.1/fp-flambda d8bb46c/fp-flambda            8.233 regression
#
#   top 10 improvements
#           benchmark                a                  b  instructions Δ%     verdict
#              owl_gc   5.4.1/baseline   d8bb46c/baseline          -31.044 improvement
#              owl_gc         5.4.1/fp         d8bb46c/fp          -31.015 improvement
#              owl_gc    5.4.1/flambda    d8bb46c/flambda          -23.740 improvement
#              owl_gc 5.4.1/fp-flambda d8bb46c/fp-flambda          -22.207 improvement
#         devkit_stre   5.4.1/baseline   d8bb46c/baseline           -4.315 improvement
# alt_ergo_unsat_smt2   5.4.1/baseline   d8bb46c/baseline           -3.474 improvement
# alt_ergo_unsat_smt2    5.4.1/flambda    d8bb46c/flambda           -1.221        warn
#         devkit_stre 5.4.1/fp-flambda d8bb46c/fp-flambda           -1.212        warn
# liq_parse_typecheck    5.4.1/flambda    d8bb46c/flambda           -0.899     neutral
# liq_parse_typecheck 5.4.1/fp-flambda d8bb46c/fp-flambda           -0.785     neutral
# #### Wall-time Δ% per pair
# #### Max RSS Δ% per pair
# #### p95 latency Δ% per pair
# #### p99 latency Δ% per pair
# #### Time × memory tradeoff
# #### Ranked tables (within block)
# wall: top 10 regressions
#           benchmark                a                  b  wall_Δ%
#         devkit_gzip   5.4.1/baseline   d8bb46c/baseline   47.429
#           zarith_pi    5.4.1/flambda    d8bb46c/flambda   16.269
#           zarith_pi 5.4.1/fp-flambda d8bb46c/fp-flambda   15.994
#           zarith_pi   5.4.1/baseline   d8bb46c/baseline   14.741
#           zarith_pi         5.4.1/fp         d8bb46c/fp   14.474
# liq_parse_typecheck   5.4.1/baseline   d8bb46c/baseline    8.595
# liq_parse_typecheck         5.4.1/fp         d8bb46c/fp    8.052
#        irmin_mem_rw   5.4.1/baseline   d8bb46c/baseline    7.407
#       menhir_sysver   5.4.1/baseline   d8bb46c/baseline    6.565
#       menhir_sysver    5.4.1/flambda    d8bb46c/flambda    6.310
#
# wall: top 10 improvements
#         benchmark                a                  b  wall_Δ%
#            owl_gc         5.4.1/fp         d8bb46c/fp  -30.112
#            owl_gc   5.4.1/baseline   d8bb46c/baseline  -29.434
#            owl_gc    5.4.1/flambda    d8bb46c/flambda  -27.411
#            owl_gc 5.4.1/fp-flambda d8bb46c/fp-flambda  -26.396
# devkit_htmlstream         5.4.1/fp         d8bb46c/fp   -8.035
# devkit_htmlstream    5.4.1/flambda    d8bb46c/flambda   -4.764
#   sedlex_tokenize 5.4.1/fp-flambda d8bb46c/fp-flambda   -2.439
#      irmin_mem_rw    5.4.1/flambda    d8bb46c/flambda   -2.371
#      irmin_mem_rw 5.4.1/fp-flambda d8bb46c/fp-flambda   -2.333
#       devkit_stre         5.4.1/fp         d8bb46c/fp   -2.000
#
# rss: top 10 regressions
#           benchmark                a                  b  rss_Δ%
#       menhir_ocamly   5.4.1/baseline   d8bb46c/baseline   9.725
# liq_parse_typecheck         5.4.1/fp         d8bb46c/fp   2.363
# liq_parse_typecheck   5.4.1/baseline   d8bb46c/baseline   2.248
#     sedlex_tokenize 5.4.1/fp-flambda d8bb46c/fp-flambda   0.040
#     sedlex_tokenize    5.4.1/flambda    d8bb46c/flambda   0.035
#      dune_bootstrap         5.4.1/fp         d8bb46c/fp   0.000
#      dune_bootstrap 5.4.1/fp-flambda d8bb46c/fp-flambda   0.000
#      dune_bootstrap    5.4.1/flambda    d8bb46c/flambda   0.000
#      dune_bootstrap   5.4.1/baseline   d8bb46c/baseline   0.000
# coqc_corelib_stress         5.4.1/fp         d8bb46c/fp   0.000
#
# rss: top 10 improvements
#           benchmark                a                  b  rss_Δ%
#          cpdf_scale 5.4.1/fp-flambda d8bb46c/fp-flambda -40.308
#          cpdf_scale    5.4.1/flambda    d8bb46c/flambda -40.131
#          cpdf_scale         5.4.1/fp         d8bb46c/fp -38.902
#          cpdf_scale   5.4.1/baseline   d8bb46c/baseline -38.756
#   devkit_htmlstream         5.4.1/fp         d8bb46c/fp -31.564
#   devkit_htmlstream   5.4.1/baseline   d8bb46c/baseline -31.487
#      cpdf_blacktext   5.4.1/baseline   d8bb46c/baseline -30.518
#      cpdf_blacktext         5.4.1/fp         d8bb46c/fp -30.439
# alt_ergo_unsat_smt2         5.4.1/fp         d8bb46c/fp -29.523
#        irmin_mem_rw   5.4.1/baseline   d8bb46c/baseline -28.998
#
# gc_overhead: top 10 regressions
#       benchmark                a                  b  gc_overhead_Δ%
#    ydump_repeat   5.4.1/baseline   d8bb46c/baseline          64.208
#    ydump_repeat         5.4.1/fp         d8bb46c/fp          60.160
#    ydump_repeat 5.4.1/fp-flambda d8bb46c/fp-flambda          59.706
#    ydump_repeat    5.4.1/flambda    d8bb46c/flambda          57.612
#    irmin_mem_rw    5.4.1/flambda    d8bb46c/flambda          35.685
#    irmin_mem_rw 5.4.1/fp-flambda d8bb46c/fp-flambda          31.606
# test_decompress   5.4.1/baseline   d8bb46c/baseline          26.471
# test_decompress         5.4.1/fp         d8bb46c/fp          25.764
#    irmin_mem_rw         5.4.1/fp         d8bb46c/fp          25.000
#    irmin_mem_rw   5.4.1/baseline   d8bb46c/baseline          24.203
#
# gc_overhead: top 10 improvements
#   benchmark                a                  b  gc_overhead_Δ%
#      owl_gc    5.4.1/flambda    d8bb46c/flambda         -62.022
#      owl_gc 5.4.1/fp-flambda d8bb46c/fp-flambda         -60.618
# devkit_gzip   5.4.1/baseline   d8bb46c/baseline         -59.211
#   zarith_pi 5.4.1/fp-flambda d8bb46c/fp-flambda         -44.505
#   zarith_pi    5.4.1/flambda    d8bb46c/flambda         -44.111
#   zarith_pi         5.4.1/fp         d8bb46c/fp         -37.725
#      owl_gc         5.4.1/fp         d8bb46c/fp         -37.605
#   zarith_pi   5.4.1/baseline   d8bb46c/baseline         -37.215
#      owl_gc   5.4.1/baseline   d8bb46c/baseline         -36.435
# devkit_gzip    5.4.1/flambda    d8bb46c/flambda         -29.167

# %% [markdown]
# ## 5. CSV export
#
# Long-form: one row per (benchmark, comparison-pair) with the median Δ% for the headline metrics. Writes to `cache/regression_report.csv`.

# %%
report_rows = []
metrics_for_report = [
    ("olly_wall_time_s", "wall_Δ%"),
    ("max_rss_mb",       "rss_Δ%"),
    ("olly_gc_overhead_pct", "gc_overhead_Δ%"),
    ("perf_instructions", "instructions_Δ%"),
    ("olly_p95_latency_ms", "p95_latency_Δ%"),
    ("olly_p99_latency_ms", "p99_latency_Δ%"),
]
for cmp in comparisons:
    for av, bv in cmp.pairs:
        per_pair = {
            "comparison": cmp.label,
            "a": av,
            "b": bv,
        }
        per_bench_metric = {}
        for metric, col in metrics_for_report:
            if metric not in df.columns or df[metric].isna().all():
                continue
            d = _delta_per_bench(df, av, bv, metric)
            for bench, v in d.items():
                per_bench_metric.setdefault(bench, {})[col] = round(float(v), 3)
        for bench, mvs in per_bench_metric.items():
            row = {**per_pair, "benchmark": bench}
            row.update(mvs)
            report_rows.append(row)

report = pd.DataFrame(report_rows)
out = Path.cwd() / "cache" / "regression_report.csv"
report.to_csv(out, index=False)
print(f"Wrote {out}  shape={report.shape}")
report.head(10)
# Out:
# Wrote /home/udesou/running-ng/notebooks/cache/regression_report.csv  shape=(260, 10)
#            comparison               a         b            benchmark  wall_Δ%  rss_Δ%  gc_overhead_Δ%  instructions_Δ%  p95_latency_Δ%  p99_latency_Δ%
# 0  5.4.1 flag effects  5.4.1/baseline  5.4.1/fp        alt_ergo_fill    5.882  -3.735          -1.005            6.795           0.541           4.241
# 1  5.4.1 flag effects  5.4.1/baseline  5.4.1/fp  alt_ergo_unsat_smt2    0.133   1.219          -1.466            7.400           1.016           0.871
# 2  5.4.1 flag effects  5.4.1/baseline  5.4.1/fp        alt_ergo_yyll    3.834  -0.018          -0.976           13.441           2.982           3.620
# 3  5.4.1 flag effects  5.4.1/baseline  5.4.1/fp  coqc_corelib_stress    0.076  -0.001           0.000            0.001           0.000           0.072
# 4  5.4.1 flag effects  5.4.1/baseline  5.4.1/fp       cpdf_blacktext    2.782  -0.200           2.489            5.885           8.145           5.100
# 5  5.4.1 flag effects  5.4.1/baseline  5.4.1/fp           cpdf_merge    4.029   0.117           1.294            5.718           6.428           1.058
# 6  5.4.1 flag effects  5.4.1/baseline  5.4.1/fp           cpdf_scale    3.006   0.262           2.184            6.047           6.764           4.242
# 7  5.4.1 flag effects  5.4.1/baseline  5.4.1/fp         cpdf_squeeze    2.556  -0.163           2.549            5.476           4.231           1.625
# 8  5.4.1 flag effects  5.4.1/baseline  5.4.1/fp          devkit_gzip   45.714  -2.148         -45.395           20.208         -24.091         -28.164
# 9  5.4.1 flag effects  5.4.1/baseline  5.4.1/fp    devkit_htmlstream   15.807   0.152          -9.264            7.084          -1.418           6.134
